# %%
from transformers import pipeline

# %%
import pandas as pd
import numpy as np
import textwrap
import matplotlib.pyplot as plt
from pprint import pprint
import torch

# %%
# !wget -nc https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/hmm_class/robert_frost.txt
# Out:
# --2026-03-13 16:54:41--  https://raw.githubusercontent.com/lazyprogrammer/machine_learning_examples/master/hmm_class/robert_frost.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 56286 (55K) [text/plain]
# Saving to: ‘robert_frost.txt’
#
# robert_frost.txt    100%[===================>]  54.97K  --.-KB/s    in 0.008s
#
# 2026-03-13 16:54:41 (6.39 MB/s) - ‘robert_frost.txt’ saved [56286/56286]

# %%
# !cat robert_frost.txt
# Out:
# Two roads diverged in a yellow wood,
# And sorry I could not travel both
# And be one traveler, long I stood
# And looked down one as far as I could
# To where it bent in the undergrowth;
#
# Then took the other, as just as fair,
# And having perhaps the better claim
# Because it was grassy and wanted wear,
# Though as for that the passing there
# Had worn them really about the same,
#
# And both that morning equally lay
# In leaves no step had trodden black.
# Oh, I kept the first for another day!
# Yet knowing how way leads on to way
# I doubted if I should ever come back.
#
# I shall be telling this with a sigh
# Somewhere ages and ages hence:
# Two roads diverged in a wood, and I,
# I took the one less traveled by,
# And that has made all the difference.
#
# Whose woods these are I think I know.
# His house is in the village, though;
# He will not see me stopping here
# To watch his woods fill up with snow.
#
# My little horse must think it queer
# ...

# %%
lines = [line.rstrip() for line in open('robert_frost.txt')]
lines = [line for line in lines if len(line) > 0]

# %%
gen = pipeline('text-generation')
# Out:
# No model was supplied, defaulted to openai-community/gpt2 and revision 607a30d.
# Using a pipeline without specifying a model name and revision in production is not recommended.
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/148 [00:00<?, ?it/s]
# GPT2LMHeadModel LOAD REPORT from: openai-community/gpt2
# Key                  | Status     |  |
# ...

# %%
lines[0]
# Out:
# 'Two roads diverged in a yellow wood,'

# %%
gen(lines[0])
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# ...

# %%
pprint(_)
# Out:
# [{'generated_text': 'Two roads diverged in a yellow wood, the first one being '
#                     'at the end of the road, and the second at the north end '
#                     'of the road. It was a small hill, only 200 yards wide, '
#                     'which stretched out from the road, along the sides of the '
#                     'road, to a point where the road was broken into. There '
#                     'was a number of small trees at the right of it, both in '
#                     'the foreground and at the end. The roads were connected '
#                     'by a thick, narrow ditch which led directly to one of the '
#                     'houses. The road was very narrow, and very narrow, and '
#                     'there were only two or three piers on either side of the '
#                     'road. The back of this ditch was covered with a layer of '
#                     'rock. The road was nearly all paved by some kind of '
# ...

# %%
pprint(gen(lines[0], max_new_tokens=20)) # max_length has less priority than max_new_tokens
# Out:
# Passing `generation_config` together with generation-related arguments=({'max_new_tokens'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'Two roads diverged in a yellow wood, each one with a few '
#                     'people watching. A man in a dark jacket and a black suit '
#                     'stood above'}]

# %%
pprint(gen(lines[0], num_return_sequences=3, max_new_tokens=20))
# Out:
# Passing `generation_config` together with generation-related arguments=({'num_return_sequences', 'max_new_tokens'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=20) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'Two roads diverged in a yellow wood, and the ground '
#                     'slowly turned to yellow. The road was still, but it was '
#                     'not a straight one'},
#  {'generated_text': 'Two roads diverged in a yellow wood, and a narrow path of '
#                     'the same colour, which lay a few miles up the road, was '
#                     'closed'},
# ...

# %%
def wrap(x):
    return textwrap.fill(x, replace_whitespace=False, fix_sentence_endings=True)

# %%
out = gen(lines[0], max_new_tokens=30)
print(wrap(out[0]['generated_text']))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=30) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Two roads diverged in a yellow wood, where the road became clear.  The
# road was a narrow channel and had been marked by numerous red blocks,
# both on the left and on the right.

# %%
prev = 'Two roads diverged in a yellow wood, where the road became clear.\n' + \
'The road was a narrow channel and had been marked by numerous red blocks,' + \
'both on the left and on the right.'

out = gen(prev + '\n' + lines[2], max_new_tokens=60)
print(wrap(out[0]['generated_text']))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=60) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Two roads diverged in a yellow wood, where the road became clear.
# The
# road was a narrow channel and had been marked by numerous red
# blocks,both on the left and on the right.
# And be one traveler, long I
# stood at the road-ends, still I saw the road-ends to my left and the
# road-ends to my right, and I saw a road-end at the left.
# And be one
# traveler, long I stood at the road-ends, still I saw the road-ends to
# my

# %%
prev = "Two roads diverged in a yellow wood, where the road became clear.\n" +\
"The road was a narrow channel and had been marked by numerous red blocks,both on the left and on the right.\n" +\
"And be one traveler, long I stood at the road-ends.\n "+\
"Still I saw the road-ends to my left and the road-ends to my right, and I saw a road-end at the left."

out = gen(prev + '\n' + lines[4], max_new_tokens=90)
print(wrap(out[0]['generated_text']))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=90) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Two roads diverged in a yellow wood, where the road became clear.
# The
# road was a narrow channel and had been marked by numerous red
# blocks,both on the left and on the right.
# And be one traveler, long I
# stood at the road-ends.
#  Still I saw the road-ends to my left and the
# road-ends to my right, and I saw a road-end at the left.
# To where it
# bent in the undergrowth; to where the road was a narrow channel, and a
# narrow channel, at the left.
# I looked towards the road-ends, but I
# could not see them.
# The road was narrow.
# The road-ends were green, and
# the road-ends were yellow, and I could see no road.
# I went out from
# ...

# %%
prompt = "Neural networks with attention have been used with great success " +\
"in natural language processing."

out = gen(prompt, max_length=50)
print(wrap(out[0]['generated_text']))
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=50) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# Neural networks with attention have been used with great success in
# natural language processing.  The results suggest that these networks
# could be used to map the neural network of a person's brain to the
# neural network of others, and to perform task-related tasks such as
# speech recognition.
#
# In this study, we investigated whether the same
# neural network could be mapped to the human brain using a new
# generation of neural networks.  While the current generation of neural
# networks are not highly trained, they can be trained to recognize the
# person's voice and can be used to perform visual recognition tasks.
# ...
