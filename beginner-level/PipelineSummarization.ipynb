# %%
# https://www.kaggle.com/shivamkushwaha/bbc-full-text-document-classification
# !wget -nc https://lazyprogrammer.me/course_files/nlp/bbc_text_cls.csv
# Out:
# File ‘bbc_text_cls.csv’ already there; not retrieving.

# %%
# !pip install --upgrade transformers

# %%
from transformers import pipeline
import pandas as pd
import numpy as np
import textwrap

# %%
df = pd.read_csv('bbc_text_cls.csv')

# %%
df.head()
# Out:
#                                                 text    labels
# 0  Ad sales boost Time Warner profit\n\nQuarterly...  business
# 1  Dollar gains on Greenspan speech\n\nThe dollar...  business
# 2  Yukos unit buyer faces loan claim\n\nThe owner...  business
# 3  High fuel prices hit BA's profits\n\nBritish A...  business
# 4  Pernod takeover talk lifts Domecq\n\nShares in...  business

# %%
doc = df[df.labels == 'business']['text'].sample(random_state=42)

# %%
def wrap(x):
    return textwrap.fill(x, replace_whitespace=False, fix_sentence_endings=True)

# %%
print(wrap(doc.iloc[0]))
# Out:
# Christmas sales worst since 1981
#
# UK retail sales fell in December,
# failing to meet expectations and making it by some counts the worst
# Christmas since 1981.
#
# Retail sales dropped by 1% on the month in
# December, after a 0.6% rise in November, the Office for National
# Statistics (ONS) said.  The ONS revised the annual 2004 rate of growth
# down from the 5.9% estimated in November to 3.2%. A number of
# retailers have already reported poor figures for December.  Clothing
# retailers and non-specialist stores were the worst hit with only
# internet retailers showing any significant growth, according to the
# ONS.
#
# The last time retailers endured a tougher Christmas was 23 years
# previously, when sales plunged 1.7%.
#
# The ONS echoed an earlier
# caution from Bank of England governor Mervyn King not to read too much
# into the poor December figures.  Some analysts put a positive gloss on
# the figures, pointing out that the non-seasonally-adjusted figures
# ...

# %%
summarizer = pipeline('text-generation', model="facebook/bart-large-cnn")
# Out:
# model.safetensors:   0%|          | 0.00/1.63G [00:00<?, ?B/s]
# Please make sure the generation config includes `forced_bos_token_id=0`.
# Loading weights:   0%|          | 0/316 [00:00<?, ?it/s]
# BartForCausalLM LOAD REPORT from: facebook/bart-large-cnn
# Key                                                       | Status     |  |
# ----------------------------------------------------------+------------+--+-
# model.encoder.layers.{0...11}.self_attn.k_proj.weight     | UNEXPECTED |  |
# model.encoder.layers.{0...11}.self_attn.out_proj.weight   | UNEXPECTED |  |
# model.encoder.layers.{0...11}.self_attn_layer_norm.weight | UNEXPECTED |  |
# model.encoder.layers.{0...11}.self_attn.q_proj.bias       | UNEXPECTED |  |
# model.encoder.layers.{0...11}.final_layer_norm.weight     | UNEXPECTED |  |
# model.encoder.layers.{0...11}.fc1.bias                    | UNEXPECTED |  |
# model.encoder.layers.{0...11}.fc1.weight                  | UNEXPECTED |  |
# ...

# %%
# import transformers
# from transformers import pipeline

# print("transformers version:", transformers.__version__)
# print("transformers file:", transformers.__file__)
# print("pipeline module:", pipeline.__module__)
# Out:
# transformers version: 5.3.0
# transformers file: /usr/local/lib/python3.12/dist-packages/transformers/__init__.py
# pipeline module: transformers.pipelines

# %%
summarizer(doc.iloc[0].split("\n", 1)[1])
# Out:
# Passing `generation_config` together with generation-related arguments=({'max_length'}) is deprecated and will be removed in future versions. Please pass either a `generation_config` object OR all generation parameters explicitly, but not both.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_27932/4130747936.py in <cell line: 0>()
# ----> 1 summarizer(doc.iloc[0].split("\n", 1)[1])
#
# /usr/local/lib/python3.12/dist-packages/transformers/pipelines/text_generation.py in __call__(self, text_inputs, **kwargs)
#     297               ids of the generated text.
#     298         """
# --> 299         return super().__call__(text_inputs, **kwargs)
#     300
#     301     def preprocess(
#
# /usr/local/lib/python3.12/dist-packages/transformers/pipelines/base.py in __call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1265             )
# ...

# %% [markdown]
# HuggingFace v5 doesn't support summarization anymore.
#
# At this point in time I lack the necessary knowledge to do summarization using anything other than pipeline, I will revisit this in the future, possibly in the intermediate or advanced parts of the course.
